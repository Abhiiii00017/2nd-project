# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import squarify as sq
import plotly.io as pio
import resample as rs

# %%
df = pd.read_csv('dataset/Unicorn_Companies.csv')
df
# Out:
#            Company Valuation ($B)       Date Joined        Country  \
# 0        Bytedance           $140     07 April 2017          China
# 1           SpaceX         $100.3  01 December 2012  United States
# 2           Stripe            $95   23 January 2014  United States
# 3           Klarna          $45.6  12 December 2011         Sweden
# 4       Epic Games            $42   26 October 2018  United States
# ...            ...            ...               ...            ...
# 1032     Timescale             $1  22 February 2022  United States
# 1033      Scalapay             $1  23 February 2022          Italy
# 1034  Omada Health             $1  23 February 2022  United States
# 1035    BlueVoyant             $1  23 February 2022  United States
# 1036          Veev             $1  24 February 2022  United States
#
#                City                      Industry  \
# 0           Beijing       Artificial intelligence
# 1         Hawthorne                         Other
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City',
#        'Industry', 'Select Inverstors', 'Founded Year', 'Total Raised',
#        'Financial Stage', 'Investors Count', 'Deal Terms', 'Portfolio Exits'],
#       dtype='object')

# %%
#drop the columns that are not needed
df.drop(['Portfolio Exits', 'Deal Terms'], axis=1, inplace=True)
df
# Out:
#            Company Valuation ($B)       Date Joined        Country  \
# 0        Bytedance           $140     07 April 2017          China
# 1           SpaceX         $100.3  01 December 2012  United States
# 2           Stripe            $95   23 January 2014  United States
# 3           Klarna          $45.6  12 December 2011         Sweden
# 4       Epic Games            $42   26 October 2018  United States
# ...            ...            ...               ...            ...
# 1032     Timescale             $1  22 February 2022  United States
# 1033      Scalapay             $1  23 February 2022          Italy
# 1034  Omada Health             $1  23 February 2022  United States
# 1035    BlueVoyant             $1  23 February 2022  United States
# 1036          Veev             $1  24 February 2022  United States
#
#                City                      Industry  \
# 0           Beijing       Artificial intelligence
# 1         Hawthorne                         Other
# ...

# %%
df.columns
# Out:
# Index(['Company', 'Valuation ($B)', 'Date Joined', 'Country', 'City',
#        'Industry', 'Select Inverstors', 'Founded Year', 'Total Raised',
#        'Financial Stage', 'Investors Count'],
#       dtype='object')

# %%
# change the column names
df= df.rename(columns={'Valuation ($B)': 'Valuation'})
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1037 entries, 0 to 1036
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Company            1037 non-null   object
#  1   Valuation          1037 non-null   object
#  2   Date Joined        1037 non-null   object
#  3   Country            1037 non-null   object
#  4   City               1037 non-null   object
#  5   Industry           1037 non-null   object
#  6   Select Inverstors  1037 non-null   object
#  7   Founded Year       1037 non-null   object
#  8   Total Raised       1037 non-null   object
#  9   Financial Stage    1037 non-null   object
#  10  Investors Count    1037 non-null   object
# dtypes: object(11)
# memory usage: 89.2+ KB

# %%
df.isnull().sum()
# Out:
# Company              0
# Valuation            0
# Date Joined          0
# Country              0
# City                 0
# Industry             0
# Select Inverstors    0
# Founded Year         0
# Total Raised         0
# Financial Stage      0
# Investors Count      0
# dtype: int64

# %%
df.describe()
# Out:
#        Company Valuation   Date Joined        Country           City Industry  \
# count     1037      1037          1037           1037           1037     1037
# unique    1035       200           623             46            256       33
# top       Bolt        $1  13 July 2021  United States  San Francisco  Fintech
# freq         2       244             9            536            145      205
#
#        Select Inverstors Founded Year Total Raised Financial Stage  \
# count               1037         1037         1037            1037
# unique              1006           37          914              10
# top                 None         2015         None            None
# freq                  17          144           24             988
#
#        Investors Count
# count             1037
# unique              54
# top                 10
# freq                69

# %% [markdown]
# # cleaning first column

# %%
df.Company.unique()
# Out:
# array(['Bytedance', 'SpaceX', 'Stripe', ..., 'Omada Health', 'BlueVoyant',
#        'Veev'], dtype=object)

# %%
df.Company.value_counts()
# Out:
# Bolt              2
# Fabric            2
# Bytedance         1
# Aibee             1
# Alation           1
#                  ..
# Voodoo            1
# Uptake            1
# KeepTruckin       1
# Skydance Media    1
# Veev              1
# Name: Company, Length: 1035, dtype: int64

# %%
df['Company'].unique().tolist()
# Out:
# ['Bytedance',
#  'SpaceX',
#  'Stripe',
#  'Klarna',
#  'Epic Games',
#  'Canva',
#  'Checkout.com',
#  'Instacart',
#  'Databricks',
#  'Revolut',
#  'FTX',
#  'Fanatics',
#  'Chime',
#  "BYJU's",
#  'Xiaohongshu',
#  'J&T Express',
#  'Miro',
#  'Yuanfudao',
#  'DJI Innovations',
#  'SHEIN',
#  'goPuff',
#  'Yuanqi Senlin',
#  'Ripple',
#  'Plaid',
#  'OpenSea',
#  'Grammarly',
#  'Devoted Health',
#  'Faire',
#  'Brex',
#  'JUUL Labs',
#  'Bitmain Technologies',
#  'Biosplice Therapeutics',
#  'GoodLeap',
#  'Airtable',
#  'ZongMu Technology',
#  'Global Switch',
#  'Celonis',
#  'Bolt',
#  'Alchemy',
#  'Weilong',
#  'Swiggy',
#  'Lalamove',
#  'Figma',
#  'Gusto',
#  'reddit',
#  'Talkdesk',
#  'Notion Labs',
#  'Thrasio',
#  'Digital Currency Group',
#  'OutSystems',
#  'ServiceTitan',
#  'HEYTEA',
#  'N26',
#  'Klaviyo',
#  'Northvolt',
#  'Tanium',
#  'Chehaoduo',
#  'Niantic',
#  'OYO Rooms',
#  'Rapyd',
#  'Kavak',
#  'Snyk',
#  'Nuro',
#  'Lacework',
#  'Tipalti',
# ...

# %% [markdown]
# # cleaning second column

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df.Valuation.unique()
# Out:
# array(['$140', '$100.3', '$95', '$45.6', '$42', '$40', '$39', '$38',
#        '$33', '$32', '$27', '$25', '$21', '$20', '$17.5', '$15.5', '$15',
#        '$13.4', '$13.3', '$13', '$12.6', '$12.4', '$12.3', '$12', '$11.7',
#        '$11.4', '$11.1', '$11', '$10.2', '$10.88', '$10.7', '$10', '$9.5',
#        '$9.28', '$9.23', '$9.2', '$9.08', '$9', '$9.6', '$8.75', '$8.7',
#        '$8.6', '$8.4', '$8.3', '$8.1', '$8', '$7.83', '$7.6', '$7.75',
#        '$7.5', '$7.4', '$7.3', '$7.25', '$7.1', '$7', '$6.8', '$6.6',
#        '$6.5', '$6.3', '$6.28', '$6.2', '$6.1', '$6', '$5.2', '$5.99',
#        '$5.78', '$5.77', '$5.7', '$5.6', '$5.3', '$5.25', '$5.1', '$5.05',
#        '$5', '$5.5', '$4.9', '$4.8', '$4.73', '$4.7', '$4.6', '$5.85',
#        '$4.58', '$4.53', '$4.5', '$4.4', '$4.3', '$4.2', '$4.25', '$4.15',
#        '$4.1', '$4.11', '$4', '$4.01', '$3.92', '$3.8', '$3.75', '$3.7',
#        '$3.6', '$3.52', '$3.5', '$3.44', '$3.4', '$3.35', '$3.32',
# ...

# %%
# drop $ sign
df['Valuation'] = df['Valuation'].str.replace('$', '')
df['Valuation'] = df['Valuation'].str.replace('B', '')
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14876\4059293257.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation'] = df['Valuation'].str.replace('$', '')

# %%
df['Valuation'] = df['Valuation'].astype(float)
df['Valuation']
# Out:
# 0       140.0
# 1       100.3
# 2        95.0
# 3        45.6
# 4        42.0
#         ...
# 1032      1.0
# 1033      1.0
# 1034      1.0
# 1035      1.0
# 1036      1.0
# Name: Valuation, Length: 1037, dtype: float64

# %%
df['Valuation'].unique()
# Out:
# array([140.  , 100.3 ,  95.  ,  45.6 ,  42.  ,  40.  ,  39.  ,  38.  ,
#         33.  ,  32.  ,  27.  ,  25.  ,  21.  ,  20.  ,  17.5 ,  15.5 ,
#         15.  ,  13.4 ,  13.3 ,  13.  ,  12.6 ,  12.4 ,  12.3 ,  12.  ,
#         11.7 ,  11.4 ,  11.1 ,  11.  ,  10.2 ,  10.88,  10.7 ,  10.  ,
#          9.5 ,   9.28,   9.23,   9.2 ,   9.08,   9.  ,   9.6 ,   8.75,
#          8.7 ,   8.6 ,   8.4 ,   8.3 ,   8.1 ,   8.  ,   7.83,   7.6 ,
#          7.75,   7.5 ,   7.4 ,   7.3 ,   7.25,   7.1 ,   7.  ,   6.8 ,
#          6.6 ,   6.5 ,   6.3 ,   6.28,   6.2 ,   6.1 ,   6.  ,   5.2 ,
#          5.99,   5.78,   5.77,   5.7 ,   5.6 ,   5.3 ,   5.25,   5.1 ,
#          5.05,   5.  ,   5.5 ,   4.9 ,   4.8 ,   4.73,   4.7 ,   4.6 ,
#          5.85,   4.58,   4.53,   4.5 ,   4.4 ,   4.3 ,   4.2 ,   4.25,
#          4.15,   4.1 ,   4.11,   4.  ,   4.01,   3.92,   3.8 ,   3.75,
#          3.7 ,   3.6 ,   3.52,   3.5 ,   3.44,   3.4 ,   3.35,   3.32,
# ...

# %%
df['Valuation'] = df['Valuation'].astype(str)
df['Valuation']
# Out:
# 0       140.0
# 1       100.3
# 2        95.0
# 3        45.6
# 4        42.0
#         ...
# 1032      1.0
# 1033      1.0
# 1034      1.0
# 1035      1.0
# 1036      1.0
# Name: Valuation, Length: 1037, dtype: object

# %%
df['Valuation'].dtype
# Out:
# dtype('O')

# %%
# remove the decimal
df['Valuation'] = df['Valuation'].str.replace('.', '')
df['Valuation']
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_14876\733350843.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df['Valuation'] = df['Valuation'].str.replace('.', '')
# 0       1400
# 1       1003
# 2        950
# 3        456
# 4        420
#         ...
# 1032      10
# 1033      10
# 1034      10
# 1035      10
# 1036      10
# Name: Valuation, Length: 1037, dtype: object

# %%
df.Valuation.unique()
# Out:
# array(['1400', '1003', '950', '456', '420', '400', '390', '380', '330',
#        '320', '270', '250', '210', '200', '175', '155', '150', '134',
#        '133', '130', '126', '124', '123', '120', '117', '114', '111',
#        '110', '102', '1088', '107', '100', '95', '928', '923', '92',
#        '908', '90', '96', '875', '87', '86', '84', '83', '81', '80',
#        '783', '76', '775', '75', '74', '73', '725', '71', '70', '68',
#        '66', '65', '63', '628', '62', '61', '60', '52', '599', '578',
#        '577', '57', '56', '53', '525', '51', '505', '50', '55', '49',
#        '48', '473', '47', '46', '585', '458', '453', '45', '44', '43',
#        '42', '425', '415', '41', '411', '40', '401', '392', '38', '375',
#        '37', '36', '352', '35', '344', '34', '335', '332', '331', '33',
#        '325', '324', '32', '315', '31', '30', '292', '29', '285', '28',
#        '277', '275', '274', '395', '27', '26', '262', '20', '25', '245',
# ...

# %%
# add cr. to the end of the number
df['Valuation'] = df['Valuation'].astype(str) + ' cr'
df['Valuation']
# Out:
# 0       1400 cr
# 1       1003 cr
# 2        950 cr
# 3        456 cr
# 4        420 cr
#          ...
# 1032      10 cr
# 1033      10 cr
# 1034      10 cr
# 1035      10 cr
# 1036      10 cr
# Name: Valuation, Length: 1037, dtype: object

# %% [markdown]
# # Cleaning third column

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df['Date Joined'].unique()
# Out:
# array(['07 April 2017', '01 December 2012', '23 January 2014',
#        '12 December 2011', '26 October 2018', '08 January 2018',
#        '02 May 2019', '30 December 2014', '05 February 2019',
#        '26 April 2018', '20 July 2021', '06 June 2012', '05 March 2019',
#        '25 July 2017', '31 March 2016', '07 April 2021',
#        '05 January 2022', '31 May 2017', '23 January 2015',
#        '03 July 2018', '08 October 2020', '01 March 2020',
#        '20 December 2019', '11 December 2018', '10 October 2019',
#        '16 October 2018', '30 October 2019', '05 October 2018',
#        '20 December 2017', '06 July 2018', '06 August 2018',
#        '13 October 2021', '15 November 2018', '03 June 2021',
#        '22 December 2016', '26 June 2018', '08 October 2021',
#        '28 October 2021', '08 May 2021', '21 June 2018',
#        '21 February 2019', '30 April 2020', '18 December 2015',
#        '31 July 2017', '03 October 2018', '01 April 2020', '15 July 2020',
# ...

# %%
# rename this columns
df.rename(columns={'Date Joined' : 'Date_Joined'})
# Out:
#            Company Valuation       Date_Joined        Country           City  \
# 0        Bytedance   1400 cr     07 April 2017          China        Beijing
# 1           SpaceX   1003 cr  01 December 2012  United States      Hawthorne
# 2           Stripe    950 cr   23 January 2014  United States  San Francisco
# 3           Klarna    456 cr  12 December 2011         Sweden      Stockholm
# 4       Epic Games    420 cr   26 October 2018  United States           Cary
# ...            ...       ...               ...            ...            ...
# 1032     Timescale     10 cr  22 February 2022  United States       New York
# 1033      Scalapay     10 cr  23 February 2022          Italy          Milan
# 1034  Omada Health     10 cr  23 February 2022  United States  San Francisco
# 1035    BlueVoyant     10 cr  23 February 2022  United States       New York
# 1036          Veev     10 cr  24 February 2022  United States      San Mateo
#
#                           Industry  \
# ...

# %%
df.dtypes
# Out:
# Company              object
# Valuation            object
# Date Joined          object
# Country              object
# City                 object
# Industry             object
# Select Inverstors    object
# Founded Year         object
# Total Raised         object
# Financial Stage      object
# Investors Count      object
# dtype: object

# %% [markdown]
# # Cleaning Forth columns

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df.Country.unique().tolist()
# Out:
# ['China',
#  'United States',
#  'Sweden',
#  'Australia',
#  'United Kingdom',
#  'Bahamas',
#  'India',
#  'Indonesia',
#  'Germany',
#  'Hong Kong',
#  'Mexico',
#  'Estonia',
#  'Canada',
#  'Turkey',
#  'South Korea',
#  'Netherlands',
#  'Israel',
#  'France',
#  'Finland',
#  'Colombia',
#  'Belgium',
#  'Brazil',
#  'Denmark',
#  'Lithuania',
#  'Austria',
#  'Ireland',
#  'Singapore',
#  'Vietnam',
#  'United Arab Emirates',
#  'Switzerland',
#  'Argentina',
#  'Spain',
#  'Japan',
#  'Luxembourg',
#  'Nigeria',
#  'Philippines',
#  'Senegal',
#  'Malaysia',
#  'Bermuda',
#  'Norway',
#  'South Africa',
#  'Chile',
#  'Thailand',
#  'Czech Republic',
#  'Croatia',
#  'Italy']

# %% [markdown]
# # Cleaning Fifth columns

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df.City.unique().tolist()
# Out:
# ['Beijing',
#  'Hawthorne',
#  'San Francisco',
#  'Stockholm',
#  'Cary',
#  'Surry Hills',
#  'London',
#  'Fintech',
#  'Jacksonville',
#  'Bengaluru',
#  'Shanghai',
#  'Jakarta',
#  'Shenzhen',
#  'Philadelphia',
#  'New York',
#  'Waltham',
#  'San Diego',
#  'Roseville',
#  'Munich',
#  'Luohe',
#  'Cheung Sha Wan',
#  'Walpole',
#  'Boston',
#  'Glendale',
#  'Berlin',
#  'Kirkland',
#  'Gurugram',
#  'Lerma de Villada',
#  'Mountain View',
#  'Tallinn',
#  'San Jose',
#  'San Mateo',
#  'Chicago',
#  'Changsha',
#  'Mumbai',
#  'Irving',
#  'Vancouver',
#  'Istanbul',
#  'Santa Clara',
#  'Seoul',
#  'Pittsburgh',
#  'Palo Alto',
#  'Hangzhou',
#  'Toronto',
#  'Amsterdam',
#  'Los Angeles',
#  'Tel Aviv',
#  'Noida',
#  'Hoboken',
#  'Brooklyn',
#  'Paris',
#  'Helsinki',
#  'Oakland',
#  'Fremont',
#  'Bogota',
#  'Brussels',
#  'Atlanta',
#  'Campinas',
#  'Sao Paulo',
#  'Melbourne',
#  'Gurgaon',
#  'Bellevue',
#  'Montreal',
#  'Copenhagen',
#  'Irvine',
# ...

# %%
# clean this column

def clean_City_column(City):
    if City == 'San Francisco':
        return 'Francisco'
    elif City == 'Lerma de Villada':
        return 'Lerma'
    elif City == 'Mobile & telecommunications':
        return 'Noida'
    elif City == 'Ho Chi Minh City':
        return 'Hochi Minh'
    elif City == 'South San Francisco':
        return 'South Francisco'
    elif City == 'E-commerce & direct-to-consumer':
        return 'Kerala'
    elif City == 'Artificial intelligence':
        return 'AI'
    elif City == 'La Plaine Saint-Denis':
        return 'La Plaine'
    elif City == 'Colorado Springs':
        return 'Colorado'
    elif City == 'Internet software & services':
        return 'UK'
    elif City == 'Supply chain, logistics, & delivery':
        return 'Odisha'
    
    return City
df['City'] = df['City'].apply(clean_City_column)

# %% [markdown]
# # Cleaning sixth column

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df.Industry.unique().tolist()
# Out:
# ['Artificial intelligence',
#  'Other',
#  'Fintech',
#  'Internet software & services',
#  'Supply chain, logistics, & delivery',
#  'Data management & analytics',
#  'Sequoia Capital, Thoma Bravo, Softbank',
#  'E-commerce & direct-to-consumer',
#  'Edtech',
#  'Hardware',
#  'Consumer & retail',
#  'Health',
#  'Auto & transportation',
#  'Finttech',
#  'Cybersecurity',
#  'Mobile & telecommunications',
#  'Travel',
#  'Kuang-Chi',
#  'Tiger Global Management, Tiger Brokers, DCM Ventures',
#  'Jungle Ventures, Accel, Venture Highway',
#  'Artificial Intelligence',
#  'Vision Plus Capital, GSR Ventures, ZhenFund',
#  'Hopu Investment Management, Boyu Capital, DC Thomson Ventures',
#  '500 Global, Rakuten Ventures, Golden Gate Ventures',
#  'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund',
#  'Sequoia Capital China, Shunwei Capital Partners, Qualgro',
#  'Dragonfly Captial, Qiming Venture Partners, DST Global',
#  'SingTel Innov8, Alpha JWC Ventures, Golden Gate Ventures',
# ...

# %%
def clean_Industry_column(Industry):
    if Industry == 'Other':
        return 'None'
    elif Industry == 'Internet software & services':
        return 'Internet services'
    elif Industry == 'Supply chain, logistics, & delivery':
        return 'Supply chain'
    elif Industry == 'Data management & analytics':
        return 'Data management'
    elif Industry == 'Sequoia Capital, Thoma Bravo, Softbank':
        return 'Sequoia Capital'
    elif Industry == 'E-commerce & direct-to-consumer':
        return 'E-commerce'
    elif Industry == 'Consumer & retail':
        return 'Consumer&retail'
    elif Industry == 'Auto & transportation':
        return 'Auto&transportation'
    elif Industry == 'Mobile & telecommunications':
        return 'Mobile&telecommunications'
    elif Industry == 'Tiger Global Management, Tiger Brokers, DCM Ventures':
        return 'Tiger Global Management'
    elif Industry == 'Jungle Ventures, Accel, Venture Highway':
        return 'Jungle Ventures'
    elif Industry == 'Artificial intelligence':
        return 'AI'
    elif Industry == 'Vision Plus Capital, GSR Ventures, ZhenFund':
        return 'Vision Plus Capital'
    elif Industry == 'Hopu Investment Management, Boyu Capital, DC Thomson Ventures':
        return 'Hopu Investment'
    elif Industry == '500 Global, Rakuten Ventures, Golden Gate Ventures':
        return 'Global'
    elif Industry == 'Sequoia Capital China, ING, Alibaba Entrepreneurs Fund':
        return 'ING'
    elif Industry == 'Sequoia Capital China, Shunwei Capital Partners, Qualgro':
        return 'Sequoia Capital China'
    elif Industry == 'Dragonfly Captial, Qiming Venture Partners, DST Global':
        return 'Dragonfly Captial'
    elif Industry == 'Dragonfly Captial, Qiming Venture Partners, DST Global':
        return 'Dragonfly Captial'
    elif Industry == 'Mundi Ventures, Doqling Capital Partners, Activant Capital':
        return 'Mundi Ventures'
    elif Industry == 'Vertex Ventures SE Asia, Global Founders Capital, Visa Ventures':
        return 'Vertex Ventures'
    elif Industry == 'Andreessen Horowitz, DST Global, IDG Capital':
        return 'DST Global'
    elif Industry == "B Capital Group, Monk's Hill Ventures, Dynamic Parcel Distribution":
        return 'B Capital Group'
    elif Industry == 'Temasek, Guggenheim Investments, Qatar Investment Authority':
        return 'Temasek'
    return Industry

df['Industry'] = df['Industry'].apply(clean_Industry_column)

# %% [markdown]
# # Cleaning Seventh column

# %%
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Select Inverstors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
df= df.rename(columns={'Select Inverstors':'Investors'})
df.columns
# Out:
# Index(['Company', 'Valuation', 'Date Joined', 'Country', 'City', 'Industry',
#        'Investors', 'Founded Year', 'Total Raised', 'Financial Stage',
#        'Investors Count'],
#       dtype='object')

# %%
def clean_Investors_column(Investors):
    if Investors == 'Sequoia Capital China, SIG Asia Investments, Sina Weibo, Softbank Group':
        return 'Softbank Group'
    elif Investors == 'Founders Fund, Draper Fisher Jurvetson, Rothenberg Ventures':
        return 'Founders Fund'
    elif Investors == 'Khosla Ventures, LowercaseCapital, capitalG':
        return 'Khosla Ventures'
    elif Investors == 'Khosla Ventures, LowercaseCapital, capitalG':
        return 'LowercaseCapital'
    elif Investors == 'Institutional Venture Partners, Sequoia Capital, General Atlantic':
        return 'Sequoia Capital'
    elif Investors == 'Tencent Holdings, KKR, Smash Ventures':
        return 'Tencent Holdings'
    elif Investors == 'Sequoia Capital China, Blackbird Ventures, Matrix Partners':
        return 'Matrix Partners'
    elif Investors == 'Tiger Global Management, Insight Partners, DST Global':
        return 'Tiger Global'
    elif Investors == 'Khosla Ventures, Kleiner Perkins Caufield & Byers, Collaborative Fund':
        return 'Collaborative Fund'
    elif Investors == 'Andreessen Horowitz, New Enterprise Associates, Battery Ventures':
        return 'Battery Ventures'
    elif Investors == 'index Ventures, DST Global, Ribbit Capital':
        return 'index Ventures'
    elif Investors == ' ':
        return 'None'
    elif Investors == 'None':
        return 'XYZ company'
    elif Investors == 'SoftBank Group, Andreessen Horowitz, Temasek Holdings':
        return 'Temasek Holdings'
    elif Investors == 'Forerunner Ventures, Crosslink Capital, Homebrew':
        return 'Forerunner Ventures'
    elif Investors == 'Tencent Holdings, Lightspeed India Partners, Sequoia Capital India':
        return 'Lightspeed Partners'
    elif Investors == 'GGV Capital, ZhenFund, Tencent':
        return 'GGV Capital'
    elif Investors == 'Hillhouse Capital Management, Boyu Capital, Sequoia Capital China':
        return 'Boyu Capital'
    elif Investors == 'Accel, AltaIR Capital, Technology Crossover Ventures':
        return 'AltaIR Capital'
    elif Investors == 'Tencent Holdings, Warbug Pincus, IDG Capital':
        return 'Warbug Pincus'
    elif Investors == 'Accel Partners, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'Tiger Global Management, Sequoia Capital China, Shunwei Capital Partners':
        return 'Shunwei Capital'
    elif Investors == 'Accel, Softbank Group, Anthos Capital':
        return 'Anthos Capital'
    elif Investors == 'Sequoia Capital China, Longfor Capitalm, Gaorong Capital':
        return 'Longfor Capitalm'
    elif Investors == 'IDG Capital, Venture51, Lightspeed Venture Partners':
        return 'Venture51'
    elif Investors == 'New Enterprise Associates, Spar Capital, Index Ventures':
        return 'Spar Capital'
    elif Investors == 'Andreessen Horowitz, Thirty Five Ventures, Sound Ventures':
        return 'Thirty Five Ventures'
    elif Investors == 'General Catalyst, Institutional Venture Partners, Breyer Capital':
        return 'Breyer Capital'
    elif Investors == 'Andreessen Horowitz, F-Prime Capital, Venrock':
        return 'F-Prime Capital'
    elif Investors == 'Khosla Ventures, Forerunner Ventures, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'DST Global, Ribbit Capital, Greenoaks Capital Management':
        return 'DST Global'
    elif Investors == 'Tiger Global Management':
        return 'Tiger Global'
    elif Investors == 'Coatue Management, Sequoia Capital China, IDG Capital':
        return 'Coatue Management'
    elif Investors == 'Vickers Venture Partners, IKEA GreenTech':
        return 'IKEA GreenTech'
    elif Investors == 'New Enterprise Associates, BDT Capital Partners, Davidson Kempner Capital Management':
        return 'BDT Capital'
    elif Investors == 'Caffeinated Capital, CRV, Founder Collective':
        return 'Caffeinated Capital'
    elif Investors == 'LTW Capital, Legend Capital, Qualcomm Ventures':
        return 'LTW Capital'
    elif Investors == 'Aviation Industry Corporation of China, Essence Financial, Jiangsu Sha Steel Group':
        return 'Essence Financial'
    elif Investors == 'Accel, 83North':
        return '83North'
    elif Investors == 'Activant Capital, Tribe Capital, General Atlantic':
        return 'Activant Capital'
    elif Investors == 'DFJ Growth Fund, Coatue Management, Addition':
        return 'DFJ Growth Fund'
    elif Investors == 'Tencent Holdings, Hillhouse Capital Management, Yunfeng Capital':
        return 'Yunfeng Capital'
    elif Investors == 'Accel India, SAIF Partners, Norwest Venture Partners':
        return 'SAIF Partners'
    elif Investors == 'MindWorks Ventures, Shunwei Capital Partners, Xiang He Capital':
        return 'Xiang He Capital'
    elif Investors == 'Index Ventures, Greylock Partners, Kleiner Perkins Caufield & Byers':
        return 'Greylock Partners'
    elif Investors == 'General Catalyst Partners, Google Ventures, Kleiner Perkins Caufield & Byers':
        return 'Google Ventures'
    elif Investors == 'Y Combinator, Sequoia Capital, Coatue Management':
        return 'Coatue Management'
    elif Investors == 'DJF, Salesforce Ventures, Storm Ventures':
        return 'DJF'
    elif Investors == 'Index Ventures, Draft Ventures, Felicis Ventures':
        return 'Draft Ventures'
    elif Investors == 'Upper90, RiverPark Ventures, Advent International':
        return 'RiverPark Ventures'
    elif Investors == 'Ribbit Capital, capitalG, Softbank Group':
        return 'capitalG'
    elif Investors == 'KKR, ES Ventures, North Bridge Growth Equity':
        return 'ES Ventures'
    elif Investors == 'Bessemer Venture Partners, ICONIQ Capital, Battery Ventures':
        return 'ICONIQ Capital'
    elif Investors == 'Sequoia Capital China, Tencent Investment, BA Capital':
        return 'BA Capital'
    elif Investors == 'Redalpine Venture Partners, Earlybird Venture Capital, Valar Ventures':
        return 'Valar Ventures'
    elif Investors == 'Summit Partners, Accel, Astral Capital':
        return 'Astral Capital'
    elif Investors == 'Vattenfall, Volkswagen Group, Goldman Sachs':
        return 'Volkswagen Group'
    elif Investors == 'Andreessen Horowitz, Nor-Cal Invest, TPG Growth':
        return 'Nor-Cal Invest'
    elif Investors == 'Sequoia Capital China, GX Capital':
        return 'GX Capital'
    elif Investors == 'Nintendo, Google, Pokemon Company International, Spark Capital':
        return 'Spark Capital'
    elif Investors == 'SoftBank Group, Sequoia Capital India,Lightspeed India Partners':
        return 'Lightspeed Partners'
    elif Investors == 'Target Global, General Catalyst, Durable Capital Partners':
        return 'Durable Capital'
    elif Investors == 'DST Global, SoftBank Group, Mountain Nazca':
        return 'Mountain Nazca'
    elif Investors == 'Tencent Holdings, Sequoia Capital China, IDG Capital':
        return 'IDG Capital'
    elif Investors == 'BOLDstart Ventures, Google Ventures, Accel':
        return 'BOLDstart Ventures'
    elif Investors == 'SoftBank Group, Greylock Partners, Gaorong Capital':
        return 'Gaorong Capital'
    elif Investors == 'Didi Chuxing, Diamler, TMT Investments':
        return 'TMT Investments'
    elif Investors == 'Tencent Holdings, Sequoia Capital China, IDG Capital':
        return 'IDG Capital'
    elif Investors == 'Sutter Hill Ventures, Liberty Global Ventures, Coatue Management':
        return 'Liberty Ventures'
    elif Investors == 'Tencent Holdings, Sequoia Capital China, IDG Capital':
        return 'BDG Capital'
    elif Investors == '01 Advisors, Zeev Ventures, Group 11':
        return 'Zeev Ventures'
    elif Investors == 'New Enterprise Associates, T. Rowe Associates, Lightbank':
        return 'Lightbank'
    elif Investors == 'KKR, Tencent Holdings, Sequoia Capital China':
        return 'Sequoia Capital China'
    elif Investors == 'Kaalari Capital, Tencent Holdings, Steadview Capital':
        return 'Steadview Capital'
    elif Investors == 'Tenaya Capital, Coatue Management, Stripes Group':
        return 'Stripes Group'
    elif Investors == 'D1 Capital Partners, Stripe, Coatue Management':
        return 'Stripe'
    elif Investors == 'Bloomberg Beta, Founders Fund, First Round Capital':
        return 'Bloomberg Beta'
    elif Investors == 'Sixth Street Partners, OrbiMed Advisors, Highland Capital Management':
        return 'OrbiMed Advisors'
    elif Investors == 'Union Square Ventures, Venrock, Andreessen Horowitz':
        return 'Union Ventures'
    elif Investors == 'Accel, Northzone Ventures, Institutional Venture Partners':
        return 'Northzone Ventures'
    elif Investors == 'Tiger Global Management, Sequoia Capital, Revo Capital':
        return 'Revo Capital'
    elif Investors == 'Lightspeed Venture Partners, Social Capital, Accel':
        return 'Social Capital'
    elif Investors == 'Sequoia Capital India, Tiger Global Management, Matrix Partners India':
        return 'Matrix Partners'
    elif Investors == 'Sequoia Capital India, Tiger Global Management, Matrix Partners India':
        return 'Sequoia Capital '
    elif Investors == 'Bessemer Venture Partners, Qualcomm Ventures, Kleiner Perkins Caufield & Byers':
        return 'Qualcomm Ventures'
    elif Investors == 'Menlo Ventures, Spark Capital, Union Square Ventures':
        return 'Menlo Ventures'
    elif Investors == 'Accel, Y Combinator, Index Ventures':
        return 'Y Combination'
    elif Investors == 'Volkswagen Group, Ford Autonomous Vehicles':
        return 'Ford Vehicles'
    elif Investors == 'Norwest Venture Partners, Next World Capital, Wing Venture Capital':
        return 'Next World Capital'
    elif Investors == 'Andreessen Horowitz, Lightspeed Venture Partners, Zeev Ventures':
        return 'Zeev Ventures'
    elif Investors == 'Morgan Creek Digital, Marcy Venture Partners, 10T Fund':
        return 'Marcy Partners'
    elif Investors == 'Tencent, Morningside Group':
        return 'Morningside Group'
    elif Investors == 'Benchmark, Greylock Partners, Tencent Holdings':
        return 'Benchmark'
    elif Investors == 'Initialized Capital, General Catalyst, SignalFire':
        return 'Initialized Capital'
    elif Investors == 'General Atlantic, Goldman Sachs, New Enterprise Associates':
        return 'Goldman Sachs'
    elif Investors == 'Slack Fund, Accel, Skip Capital':
        return 'Skip Capital'
    elif Investors == 'Sequoia Capital China, Warburg Pincus, General Catalyst':
        return 'Warburg Pincus'
    elif Investors == 'TA Associates, SoftBank Group, GS Growth':
        return 'GS Growth'
    elif Investors == 'Technology Crossover Ventures':
        return 'Technology Crossover'
    elif Investors == 'Initialized Capital, Y Combinator, Kleiner Perkins Caufield & Byers':
        return 'Kleiner Perkins'
    elif Investors == 'Accel Partners, SoftBank Group, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'New Enterprise Associates, Accomplice, IA Ventures':
        return 'IA Ventures'
    elif Investors == 'Global Founders Capital, Nortzone Ventures, Picus Capital':
        return 'Picus Capital'
    elif Investors == 'Union Square Ventures, Ribbit Capital, VY Capital':
        return 'VY Capital'
    elif Investors == 'Atomico, Insight Partners, Coatue Management':
        return 'Insight Partners'
    elif Investors == 'Thrive Capital, Benchmark, MenloVentures':
        return 'MenloVentures'
    elif Investors == 'Warmsun Holding, IDG Capital Partners':
        return 'Warmsun Holding'
    elif Investors == 'Pine Brook, American Express Ventures, Kleiner Perkins Caufield & Byers':
        return 'Pine Brook'
    elif Investors == 'Insight Partners, Sequoia Capital, Index Ventures':
        return 'Insight Partners'
    elif Investors == 'BlackRock, Blackstone, UBS':
        return 'BlackRock'
    elif Investors == 'Sequoia Capital India, Temasek, PayPal Ventures':
        return 'PayPal Ventures'
    elif Investors == 'Venrock, Battery Ventures, Insight Partners':
        return 'Battery Ventures'
    elif Investors == 'NextView Ventures, Eniac Ventures, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'Alibaba Group, Boyu Capital, Borui Capital':
        return 'Boyu Capital'
    elif Investors == 'Tencent, Baidu, Huasheng Capital':
        return 'Huasheng Capital'
    elif Investors == 'Technology Crossover Ventures, A&E Television Networks':
        return 'A&E Networks'
    elif Investors == 'Thrive Capital, Maverick Ventures, Redpoint Ventures':
        return 'Maverick Ventures'
    elif Investors == 'Battery Ventures, Storm Ventures, Redpoint Ventures':
        return 'Storm Ventures'
    elif Investors == 'Aglae Ventures, Eurazeo, Daphni':
        return 'Daphni'
    elif Investors == 'Blackstone, Technology Crossover Ventures, Summit Partners':
        return 'Summit Partners'
    elif Investors == 'Nexus Venture Partners, CRV, Insight Partners':
        return 'Nexus Partners'
    elif Investors == 'Matrix Partners, Andreessen Horowitz, General Catalyst':
        return 'General Catalyst'
    elif Investors == 'Sequoia Capital China, IDG Capital, DCM Ventures':
        return 'DCM Ventures'
    elif Investors == 'Founders Fund. Accel, Creandum':
        return 'Creandum'
    elif Investors == 'DST Global, Andreessen Horowitz, Sequoia Capital, Redpoint e.ventures':
        return 'Redpoint ventures'
    elif Investors == 'Index Ventures, Battery Ventures, ICONIQ Capital':
        return 'ICONIQ Capital'
    elif Investors == 'Lightspeed Venture Partners, Google Ventures, Lakestar':
        return 'Lakestar'
    elif Investors == 'Kaszek Ventures, General Atlantic, SoftBank Group':
        return 'General Atlantic'
    elif Investors == 'China Life Insurance, China Development Bank Capital, CITIC Securities International':
        return 'CITIC Securities'
    elif Investors == 'Ant Financial Services Group, GGV Capital':
        return 'Ant Financial'
    elif Investors == 'Andreessen Horowitz, Spark Capital, Y Combinator':
        return 'Y Combinator'
    elif Investors == 'DST Global, Sequoia Capital China, Tencent Holdings':
        return 'Tencent Holdings'
    elif Investors == 'Runa Capital, Acton Capital Partners, Point Nine Capital':
        return 'Point Nine Capital'
    elif Investors == 'Hillhouse Capital Management, Linear Venture, Morningside Venture Capital':
        return 'Linear Venture'
    elif Investors == 'Baidu Capital, Linear Venture, Tencent':
        return 'Baidu Capital'
    elif Investors == 'General Atlantic, 3i Group, Huagai Capital':
        return 'Huagai Capital'
    elif Investors == 'Walden International, Google Ventures, Intel Capital':
        return 'Intel Capital'
    elif Investors == 'Accel, Technology Crossover Ventures, LeapFrog Investments':
        return 'LeapFrog Investments'
    elif Investors == 'Clermont Group, Coltrane Asset Management, Toscafund Asset Management':
        return 'Clermont Group'
    elif Investors == 'Insight Partners, Andalusian Capital Partners':
        return 'Andalusian Capital'
    elif Investors == 'Matrix Partners India, Falcon Edge Capital, SoftBank Group':
        return 'Falcon Capital'
    elif Investors == 'Google Ventures, Benchmark, FirstMark Capital':
        return 'FirstMark Capital'
    elif Investors == 'Alven Capital, Valar Ventures, Tencent Holdings':
        return 'Valar Ventures'
    elif Investors == 'SoftBank Group, Tiger Global Management, Matrix Partners India':
        return 'Matrix Partners'
    elif Investors == 'Eight Roads Ventures, Greycroft, Ignition Partners':
        return 'Ignition Partners'
    elif Investors == 'Capital One Growth Ventures, Citi Ventures, OMERS Ventures':
        return 'OMERS Ventures'
    elif Investors == 'Venture Highway, Sequoia Capital India, Prosus Ventures':
        return 'Prosus Ventures'
    elif Investors == 'Oak HC/FT Partners, Artis Ventures, WestCap Group':
        return 'WestCap Group'
    elif Investors == 'Kaszek Ventures, Amadeus Capital Partners, Quona Capital':
        return 'Quona Capital'
    elif Investors == 'China Grand Prosperity Investment, Silk Road Huacheng, Oriza Equity Investment':
        return 'Oriza Equity'
    elif Investors == 'Creandum, Founders, Kinnevik':
        return 'Kinnevik'
    elif Investors == 'Andreessen Horowitz, Founders Fund, Revolution Ventures':
        return 'Revolution Ventures'
    elif Investors == 'Greylock Partners, Venrock, Providence Ventures':
        return 'Providence Ventures'
    elif Investors == 'Alven Capital, FirstMark Capital, capitalG':
        return 'capitalG'
    elif Investors == 'Y Combinator, Accel, T. Rowe Price':
        return 'T.Rowe Price'
    elif Investors == 'General Catalyst, Viking Global Investors, T. Rowe Price':
        return 'General Catalyst'
    elif Investors == 'Telling Telecommunication Holding Co., Alibaba Group':
        return 'Alibaba Group'
    elif Investors == 'Accel, Insight Partners, Burda Principal Investments':
        return 'Burda Principal'
    elif Investors == 'Sequoia Capital China, Tencent Holdings, Sinovation Ventures':
        return 'Sinovation Ventures'
    elif Investors == 'Two Sigma Ventures, Flint Capital, Commerce Ventures':
        return 'Commerce Ventures'
    elif Investors == 'Passion Capital, Thrive Capital, Orange Digital Ventures':
        return 'Orange Digital'
    elif Investors == 'CDH Investments, Goldstone Investments, Qiming Venture Partners':
        return 'Qiming Venture'
    elif Investors == 'Mayfield Fund, M12, Trinity Ventures':
        return 'Trinity Ventures'
    elif Investors =='Atop Capital, IDInvest Partners, Qiming Venture Partners':
        return 'Qiming Venture'
    elif Investors == 'Threshold Ventures, Lightspeed Venture Partners, Crosslink Capital':
        return 'Crosslink Capital'
    elif Investors == 'Lightspeed Venture Partners, Redpoint Ventures, Viking Global Investors':
        return 'Viking Global'
    elif Investors == 'Benchmark, Accel, SoftBank Group':
        return 'Benchmark'
    elif Investors == 'Playground Global, Bond, Tribe Capital':
        return 'Tribe Capital'
    elif Investors == 'Sequoia Capital China, Qiming Venture Partners, Tencent Holdings':
        return 'Tencent Holdings'
    elif Investors == 'Addition, Benhcmark, Accel':
        return 'Benhcmark'
    elif Investors == 'Andreessen Horowitz, Founders Fund, Revolution Ventures':
        return 'Revolution Ventures'
    elif Investors == 'Lightspeed Venture Partners, Khosla Ventures, Geodesic Capital':
        return 'Geodesic Capital'
    elif Investors == 'Vista Equity Partners, Wincove, TDR Capital':
        return 'TDR Capital'
    elif Investors == 'Andreessen Horowitz, Amplify Partners, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'Venrock, Institutional Venture Partners, Goldman Sachs':
        return 'Goldman Sachs'
    elif Investors == 'Speedinvest, Valar Ventures, Uniqa Ventures':
        return 'Uniqa Ventures'
    elif Investors == 'Goodwater Capital, iFly, XVC Venture Capital':
        return 'XVC Venture'
    elif Investors == 'New Enterprise Associates, Sequoia Capital, Comcast Ventures':
        return 'Comcast Ventures'
    elif Investors == 'Tiger Global Management, DST Global, Sequoia Capital India':
        return 'Sequoia Capital'
    elif Investors == 'Formation 8':
        return 'Formation'
    elif Investors == 'Ant Financial Services Group, Russia-China Investment Fund, Foxconn Technology Company':
        return 'Foxconn Technology'
    elif Investors == 'SoftBank Group, General Atlantic':
        return 'General Atlantic'
    elif Investors == 'Khosla Ventures, Horizons Ventures, Temasek Holdings':
        return 'Temasek Holdings'
    elif Investors == 'New Enterprise Associates, Starr Investment Holdings':
        return 'Starr Investment'
    elif Investors == 'Zeev Ventures, Ribbit Capital, TLV Partners':
        return 'TLV Partners'
    elif Investors == 'Index Ventures, Thrive Capital, CRV':
        return 'CRV'
    elif Investors == 'Dragoneer Investment Group, Hellman & Friedman, JMI Equity':
        return 'JMI Equity'
    elif Investors == 'Sequoia Capital, Bessemer Venture Partners, Threshold Ventures':
        return 'Threshold Ventures'
    elif Investors == 'Andreessen Horowitz, TQ Ventures':
        return 'TQ Ventures'
    elif Investors == 'Accel, Insight Partners, Bond Capital':
        return 'Bond Capital'
    elif Investors == 'Drive Capital, General Catalyst, Ascension Ventures':
        return 'Ascension Ventures'
    elif Investors == 'Greylock Partners, Lightspeed Venture Partners, Khosla Ventures':
        return 'Khosla Ventures'
    elif Investors == 'Accel, Aleph, American Express Ventures':
        return 'American Express'
    elif Investors == 'SoftBank Group, Norwest Venture Partners':
        return 'Norwest Venture'
    elif Investors == 'Georgian Partners, Craft Ventures':
        return 'Craft Ventures'
    elif Investors == 'Benchmark, Foundation Capital, Sequoia Capital':
        return 'Sequoia Capital'
    elif Investors == 'Blackrock, Kleiner Perkins Caulfield & Byers, Google Ventures':
        return 'Google Ventures'
    elif Investors == 'New Enterprise Associates, Pear, Cowboy Ventures':
        return 'Cowboy Ventures'
    elif Investors == 'Fifth Wall Ventures, Energize Ventures, \tICONIQ Capital':
        return 'ICONIQ Capital'
    elif Investors == 'China Health Industry Investment Fund, China Renaissance, and Sequoia Capital China':
        return 'China Renaissancel'
    elif Investors == 'New Enterprise Associates, New Leaf Venture Partners, Charter Venture Capital':
        return 'Charter Venture'
    elif Investors == 'Google Ventures, Battery Ventures, DST Global':
        return 'DST Global'
    elif Investors == 'Y Combinator, Atomico, Accel':
        return 'Atomico'
    elif Investors == 'General Atlantic, Blackstone, ICONIQ Growth':
        return 'Blackstone'
    elif Investors == 'Blackstone, ICONIQ Growth, General Atlantic':
        return 'General Atlantic'
    elif Investors == 'Tiger Global Management, American Express Ventures, B Capital Group':
        return 'B Capital Group'
    elif Investors == 'Casa Verde Capital, Gron Ventures, Thrity Five Ventures':
        return 'Thrity Five Ventures'
    elif Investors == 'SoftBank Group, Sequoia Capital, Wing Venture Capital':
        return 'Wing Venture'
    elif Investors == 'Norwest Venture Partners, Goldman Sachs, Dell Technologies Capital':
        return 'Dell Technologies'
    elif Investors == 'Upfront Ventures, Webb Investment Network, D1 Capital Partners':
         return 'D1 Capital' 
    elif Investors == 'Qualcomm Ventures, Samsung Ventures, Silver Lake':
        return 'Samsung Ventures'
    elif Investors == 'Breakthrough Energy Ventures, Capricorn Investment Group, Valor Equity Partners':
        return 'Valor Equity'
    elif Investors == 'Bessemer Venture Partners, Insight Partners, New Era Ventures':
        return 'New Era Ventures'
    elif Investors == 'India Quotient, Elevation Capital, Lightspeed Venture Partners':
        return 'Elevation Capital'
    elif Investors == 'Silver Lake, ICONIQ Capital':
        return 'Silver Lake'
    elif Investors == 'NextView Ventures, Promus Ventures, Two Sigma Ventures':
        return 'Promus Ventures'
    elif Investors == 'Andreessen Horowitz, Lux Capital, General Catalyst':
        return 'General Catalyst'
    elif Investors == 'NewView Capital, Maveron, Ridge Ventures':
        return 'Ridge Ventures'




    
        
        
    

    return Investors
df['Investors'] = df['Investors'].apply(clean_Investors_column)

# %%
df['Investors'].unique().tolist()
# Out:
# ['Softbank Group',
#  'Founders Fund',
#  'Khosla Ventures',
#  'Sequoia Capital',
#  'Tencent Holdings',
#  'Matrix Partners',
#  'Tiger Global',
#  'Collaborative Fund',
#  'Battery Ventures',
#  'index Ventures',
#  'XYZ company',
#  'Temasek Holdings',
#  'Forerunner Ventures',
#  'Lightspeed Partners',
#  'GGV Capital',
#  'Boyu Capital',
#  'AltaIR Capital',
#  'Warbug Pincus',
#  'Shunwei Capital',
#  'Anthos Capital',
#  'Longfor Capitalm',
#  'Venture51',
#  'Spar Capital',
#  'Thirty Five Ventures',
#  'Breyer Capital',
#  'F-Prime Capital',
#  'DST Global',
#  'Coatue Management',
#  'IKEA GreenTech',
#  'BDT Capital',
#  'Caffeinated Capital',
#  'LTW Capital',
#  'Essence Financial',
#  '83North',
#  'Activant Capital',
#  'DFJ Growth Fund',
#  'Yunfeng Capital',
#  'SAIF Partners',
#  'Xiang He Capital',
#  'Greylock Partners',
#  'Google Ventures',
#  'DJF',
#  'Draft Ventures',
#  'RiverPark Ventures',
#  'capitalG',
#  'ES Ventures',
#  'ICONIQ Capital',
# ...
